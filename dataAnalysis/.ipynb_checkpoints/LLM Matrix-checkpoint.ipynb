# %% [markdown]
# <h1 style="text-align:center;">
# LLM Matrix
# </h1>
#
# ### Table Of Contents:
# * [Workbook Filter](#1)
# * [Matrix Plot](#2)

# %% [markdown]
# ## **1** Filtering out Relevant Columns <a class="anchor" id="1"></a>
#
# We only want the `model` name, `x_score`, and `y_score` for the final matrix from the LLM Matrix file

# %%
# Importing Librarires
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read in file
df = pd.read_excel('LLM Matrix.xlsx')

# %%
# Have a look at the first few rows
df.head()
# Out:
#   Unnamed: 0    Unnamed: 1             Unnamed: 2           Unnamed: 3  \
# 0        NaN           NaN                    NaN                  NaN
# 1      model  organisation         specialisation           created_at
# 2      GPT-4        OpenAI  General Purpose Model  2023-03-14 00:00:00
# 3      GPT-3        OpenAI                    NaN  2020-06-11 00:00:00
# 4      GPT-2        OpenAI                    NaN  2019-11-01 00:00:00
#
#   Business Rediness - > x-axis         Unnamed: 5  \
# 0                  credibility                NaN
# 1            cred_track_record  cred_endorsements
# 2                            3                  2
# 3                          NaN                NaN
# 4                          NaN                NaN
#
#                               Unnamed: 6  Unnamed: 7      Unnamed: 8  \
# 0                                    NaN         NaN     harmfulness
# 1  cred_recognition_reputable_institutes  cred_score  harm_incidents
# 2                                      3    2.666667               2
# 3                                    NaN         NaN             NaN
# 4                                    NaN         NaN             NaN
#
#         Unnamed: 9  ... Unnamed: 22  Unnamed: 23 Unnamed: 24  \
# 0              NaN  ...         NaN          NaN         NaN
# 1  harm_safeguards  ...   estimated  bench_score     x_score
# 2                3  ...         NaN     3.040667    2.690967
# 3              NaN  ...         NaN          NaN         NaN
# 4              NaN  ...         NaN          NaN         NaN
#
#   Percieved Business Value --> y-axis      Unnamed: 26   Unnamed: 27  \
# 0                                 NaN              NaN    popularity
# 1                       capabailities  success stories  pop_activity
# 2                            3.108571             3.22             4
# 3                                 NaN              NaN           NaN
# 4                                 NaN              NaN           NaN
#
#        Unnamed: 28  Unnamed: 29 Unnamed: 30 Unnamed: 31
# 0              NaN          NaN         NaN         NaN
# 1  pop_growth_rate  pop_variety   pop_score     y_score
# 2                4          3.5    3.833333    3.317619
# 3              NaN          NaN         NaN         NaN
# 4              NaN          NaN         NaN         NaN
#
# [5 rows x 32 columns]

# %%
# The headers are in the second row (iloc[1]) so rename:
df.rename(columns=df.iloc[1], inplace = True)

# %%
# Drop of the first two rows
df.drop([0,1], inplace = True)

# %%
# DataFrame with relevant coulmns only
relv_only = df[['model', 'x_score', 'y_score']]

# %%
# Have a look
relv_only
# Out:
#            model   x_score   y_score
# 2          GPT-4  2.690967  3.317619
# 3          GPT-3       NaN       NaN
# 4          GPT-2       NaN       NaN
# 5        Llama 3  2.421198       3.1
# 6         Gemini  1.649661  2.658333
# 7             T5       NaN       NaN
# 8          GPT-J       NaN       NaN
# 9    Megatron-LM       NaN       NaN
# 10         BLOOM       NaN       NaN
# 11     ERNIE 4.0       NaN       NaN
# 12  BloombergGPT  2.969775       NaN
# 13         MedLM       NaN       NaN
# 14    Med-Gemini       NaN       NaN
# 15    EXAONE 2.0     2.749  1.956667

# %%
# Filter out rows with null scores (i.e. give df with both x and y scores)
relv_only.dropna(subset=['x_score', 'y_score'], inplace=True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19552\2712994657.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   relv_only.dropna(subset=['x_score', 'y_score'], inplace=True)

# %%
# Have a look
relv_only
# Out:
#          model   x_score   y_score
# 2        GPT-4  2.690967  3.317619
# 5      Llama 3  2.421198       3.1
# 6       Gemini  1.649661  2.658333
# 15  EXAONE 2.0     2.749  1.956667

# %%
# Save as file
relv_only.to_csv('relevant_cols_only.csv', encoding='utf-8', index=False)

# %% [markdown]
# # **2** LLM Matrix Plot <a class="anchor" id="2"></a>
# Plot the matrix!

# %%
## Plot the datapoints
sns.scatterplot(data=relv_only,
                x = 'x_score',
                y='y_score',
                hue = 'model',
                #legend = False
               )

## Adjust Axis Range
 # Set the x-axis range
plt.xlim([0, 4])
 # Set the y-axis range
plt.ylim([0, 4])

## Add Quadrant Lines
 # Add a vertical line at x=2
plt.axvline(x=2, color='b', linestyle='--', linewidth=1)
 # Add a horizontal line at y=2
plt.axhline(y=2, color='b', linestyle='--', linewidth=1)

## Label the Graph
 # Add graph title
plt.title('LLM Matrix \n',
          fontweight = 'bold' )
 # Rename x-axis
plt.xlabel('Business Readiness')
 # Rename y-axis
plt.ylabel('Percieved Business Value')

## Place the legend outside the plot
plt.legend(bbox_to_anchor=(1.05, 1), 
           loc='upper left', 
           borderaxespad=0.)

## Annotate each point with its species label
for i in range(len(relv_only)):
    plt.text(x=relv_only.iloc[i]['x_score'], 
             y=relv_only.iloc[i]['y_score'], 
             s=relv_only.iloc[i]['model'],
             fontsize=9, 
             ha='left')
    
## Label each quadrant
 # Top-right quadrant
plt.text(3.5, 3.7, 'High Credability\nHigh Capability', fontsize=8, ha='center', fontweight='bold')
 # Top-left quadrant
plt.text(0.5, 3.7, 'Low Credability\nHigh Capability', fontsize=8, ha='center', fontweight='bold')
 # Bottom-right quadrant
plt.text(3.5, 0.2, 'High Credability\nLow Capability', fontsize=8, ha='center', fontweight='bold')
 # Bottom-left quadrant
plt.text(0.5, 0.2, 'Low Credability\nLow Capability', fontsize=8, ha='center', fontweight='bold')

## Show plot
plt.show()
